# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

# %%
df = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/Product Sentiments.csv") # Or provide path
df.head()
# Out:
#   Sentiment                          Time  Product  Username  \
# 0  Positive  Mon May 11 03:17:40 UTC 2009  kindle2    tpryan
# 1  Positive  Mon May 11 03:18:03 UTC 2009  kindle2    vcu451
# 2  Positive  Mon May 11 03:18:54 UTC 2009  kindle2    chadfu
# 3  Positive  Mon May 11 03:19:04 UTC 2009  kindle2     SIX15
# 4  Positive  Mon May 11 03:21:41 UTC 2009  kindle2  yamarama
#
#                                              Comment
# 0  @stellargirl I loooooooovvvvvveee my Kindle2. ...
# 1  Reading my kindle2...  Love it... Lee childs i...
# 2  Ok, first assesment of the #kindle2 ...it fuck...
# 3  @kenburbary You'll love your Kindle2. I've had...
# 4  @mikefish  Fair enough. But i have the Kindle2...

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# %%
text = df['Comment'].values
plt.figure(figsize = (60,60))
word_cloud = WordCloud(width = 1000, height = 800,collocations = False, background_color = 'white').generate(str(text))
plt.imshow(word_cloud, interpolation='bilinear')
plt.axis("off")
plt.show()
